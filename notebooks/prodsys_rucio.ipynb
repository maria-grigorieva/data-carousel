# %%
import pandas as pd 
import matplotlib.pyplot as plt
import re

# %%
df = pd.read_csv('results.csv')

# %%
required_columns = ['rule', 'resource', 'files', 'asctime', 'dataset']

# %%
reduced_df = df[required_columns]

# %%
reduced_df.to_csv('reduced_results.csv', index=False)

# %%
reduced_df.sort_values(by=['asctime'], inplace=True)
# Out:
# /tmp/ipykernel_117007/2691685458.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df.sort_values(by=['asctime'], inplace=True)

# %%
reduced_df = pd.read_csv('reduced_results.csv')

# %%
reduced_df.head()
# Out:
#                                    rule       resource  files  \
# 0  type=DATADISK&datapolicynucleus=True  IN2P3-CC_TAPE   2987
# 1  type=DATADISK&datapolicynucleus=True  IN2P3-CC_TAPE     38
# 2  type=DATADISK&datapolicynucleus=True  IN2P3-CC_TAPE   1499
# 3  type=DATADISK&datapolicynucleus=True  IN2P3-CC_TAPE    703
# 4  type=DATADISK&datapolicynucleus=True  FZK-LCG2_TAPE   2524
#
#                    asctime                                            dataset
# 0  2021-12-09 20:26:09,854  data16_13TeV:data16_13TeV.00307656.physics_Bph...
# 1  2021-12-09 20:26:10,250  data16_13TeV:data16_13TeV.00310015.physics_Bph...
# 2  2021-12-09 20:26:10,613  data16_13TeV:data16_13TeV.00310249.physics_Bph...
# 3  2021-12-09 20:26:10,939  data16_13TeV:data16_13TeV.00310969.physics_Bph...
# 4  2021-12-10 02:26:10,490  data16_13TeV:data16_13TeV.00303943.physics_Bph...

# %%
reduced_df['asctime'] = pd.to_datetime(reduced_df['asctime'])
# Out:
# /tmp/ipykernel_127507/3966752973.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   reduced_df['asctime'] = pd.to_datetime(reduced_df['asctime'])

# %%
# Function to extract the scope from dataset names
def extract_scope(dataset_name):
    if ":" in dataset_name:
        return dataset_name.split(":")[0]  # Take part before the colon
    else:
        return dataset_name.split(".")[0]  # Otherwise, take part before the first dot

# %%
# Extract scopes and get unique values
unique_scopes = reduced_df['dataset'].apply(extract_scope).unique().tolist()

# Print the result
print(unique_scopes)
# Out:
# ['data16_13TeV', 'data17_5TeV', 'mc16_13TeV', 'data17_13TeV', 'data15_13TeV', 'data18_13TeV', 'mc16_5TeV', 'valid1', 'mc15_13TeV', 'data18_hi', 'mc20_13TeV', 'mc15_14TeV', 'mc16_pPb8TeV', 'data22_13p6TeV', 'mc15_5TeV', 'data15_hi', 'data16_hip5TeV', 'data18_900GeV', 'data22_cos', 'data23_13p6TeV', 'data23_900GeV', 'data23_cos', 'data22_hi', 'data17_cos', 'data18_cos', 'data16_cos', 'mc23_13p6TeV', 'data23_hi', 'mc21_13p6TeV', 'mc21_14TeV', 'data24_13p6TeV', 'data16_hip8TeV', 'data24_5p36TeV']

# %%
reduced_df.dtypes
# Out:
# rule                object
# resource            object
# files                int64
# asctime     datetime64[ns]
# dataset             object
# dtype: object

# %%
# Group by date (without time) and count records
daily_counts = reduced_df.groupby(reduced_df['asctime'].dt.date).size()

# Plot the results
plt.figure(figsize=(12, 6))
daily_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.xlabel('Date')
plt.ylabel('Number of Records')
plt.title('Number of Records per Day')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
feb_2024.shape
# Out:
# (2569, 5)

# %%
import re

def parse_scope(scope):
    # Initialize parsed dictionary
    parsed = {
        "dataset_origin": None,
        "year": None,
        "energy": None,
        "b_unit": None,
        "dataset_category": None
    }

    # Regex to capture dataset origin and optional year + energy
    pattern = r"^(?P<dataset_origin>mc|data|valid)(?P<year>\d{2})?(?:_(?P<energy>[0-9p]+)(?P<b_unit>TeV|GeV))?"

    match = re.match(pattern, scope)
    
    if match:
        parsed.update(match.groupdict())

        # Convert energy like "13p6" -> "13.6"
        if parsed["energy"]:
            parsed["energy"] = parsed["energy"].replace("p", ".")

        # Identify dataset category based on specific keywords
        if "hi" in scope:
            parsed["dataset_category"] = "heavy_ion"
        elif "cos" in scope:
            parsed["dataset_category"] = "cosmic"
        elif "pPb" in scope or "hip" in scope:
            parsed["dataset_category"] = "proton_lead"
        else:
            parsed["dataset_category"] = "standard"

        # If "valid" scope, ignore any numbers after it
        if parsed["dataset_origin"] == "valid":
            parsed["year"] = None  # Ignore the year for validation datasets

    else:
        print(f"Failed to match dataset origin with pattern: {scope}")
        parsed["dataset_category"] = "unknown"

    return parsed

# %%
# Function to parse the full dataset name
def parse_full_dataset_name(dataset_name):
    # Split the dataset name by colon
    parts = dataset_name.split(":")
    scope = parts[0]
    # print(parts)
    # print(len(parts))
    if len(parts) != 2:
        scope = dataset_name.split(".")[0]
    
    # Parse the first part using parse_dataset_name
    dataset_info = parse_scope(scope)
    if dataset_info is None:
        print(f"Failed to parse dataset origin: {scope}")
        return None  # Skip dataset names where the first part doesn't match
    
    # Split the second part by dots
    if len(parts) > 1:
        second_part = parts[1].split(".")
    else:
        second_part = dataset_name.split(".")
    
    # Extract the entities from the second part
    datasetid = second_part[1]  # First column is datasetid
    physics_process = second_part[2]
    production_step = second_part[3]
    data_format = second_part[4] 
    ami_tags = None
    taskid = None
    if len(second_part) > 5: 
        ami_tags = re.sub(r'_tid.*', '', second_part[5])
        taskid_with_tid = second_part[-1]  
        match = re.search(r'_tid(\d+)', taskid_with_tid)  # Regex to capture digits after '_tid'
        if match:
            taskid = match.group(1)  # Return the captured group (the number after '_tid')
        else:
            taskid = None  # Return '' if '_tid' is not found
    #taskid = taskid_with_tid.replace('_tid', '') if taskid_with_tid else ''
    
    # Return the parsed data as a dictionary
    parsed_data = {
        "dataset_origin": dataset_info['dataset_origin'],
        "year": dataset_info['year'],
        "energy": dataset_info['energy'],
        "b_unit": dataset_info['b_unit'],
        "datasetid": datasetid,
        "physics_process": physics_process,
        "production_step": production_step,
        "data_format": data_format,
        "ami_tags": ami_tags,
        "root_taskID": taskid
    }
    
    return parsed_data

# %%
# Apply the parse_full_dataset_name function to the dataset_name column
parsed_columns = reduced_df['dataset'].apply(parse_full_dataset_name).apply(pd.Series)

# Check if parsing worked
print("Parsed Results:")
print(parsed_columns)
# Out:
# Parsed Results:
#        dataset_origin year energy b_unit datasetid       physics_process  \
# 0                data   16     13    TeV  00307656  physics_BphysDelayed
# 1                data   16     13    TeV  00310015  physics_BphysDelayed
# 2                data   16     13    TeV  00310249  physics_BphysDelayed
# 3                data   16     13    TeV  00310969  physics_BphysDelayed
# 4                data   16     13    TeV  00303943  physics_BphysDelayed
# ...               ...  ...    ...    ...       ...                   ...
# 119711           data   18     13    TeV  00363096          physics_Main
# 119712           data   18     13    TeV  00351160       physics_BphysLS
# 119713           data   18     13    TeV  00363129          physics_Main
# 119714           data   15     13    TeV  00276952          physics_Main
# 119715           data   15     13    TeV  00280231          physics_Main
#
#        production_step data_format     ami_tags root_taskID
# 0                merge         AOD  r9264_p3083    11270363
# 1                merge         AOD  r9264_p3083    11270399
# 2                merge         AOD  r9264_p3083    11270407
# 3                merge         AOD  r9264_p3083    11270433
# 4                merge         AOD  r9264_p3083    11270261
# ...                ...         ...          ...         ...
# 119711           merge         AOD  f1005_m2037        None
# 119712           merge         AOD   f969_m2020        None
# 119713           merge         AOD   f993_m2032        None
# 119714           merge         AOD  r9264_p3083    11253221
# 119715           merge         AOD  r9264_p3083    11234856
#
# [119716 rows x 10 columns]

# %%
reduced_df = pd.concat([reduced_df, parsed_columns], axis=1)

# %%
reduced_df.to_csv('reduced_results_enriched.csv', index=False)

# %%
prodsys_logs = pd.read_csv('reduced_results_enriched.csv')

# %%
tasks_df = pd.read_csv('tasks_2025.csv')

# %%
tasks_df.head(10)
# Out:
#      TASKID                                       INPUTDATASET  PR_ID  \
# 0  43169310  mc20_13TeV.700602.Sh_2212_llvv_os.deriv.DAOD_P...  61345
# 1  43169396  mc20_13TeV.364706.Pythia8EvtGen_A14NNPDF23LO_j...  61345
# 2  43169449  mc20_13TeV.407342.PhPy8EG_A14_ttbarHT1k5_hdamp...  61345
# 3  43169495  mc20_13TeV.700338.Sh_2211_Wenu_maxHTpTV2_BFilt...  61345
# 4  43169507  mc20_13TeV.700362.Sh_2211_Wenu2jets_Min_N_TCha...  61345
# 5  43169588  mc23_13p6TeV.700779.Sh_2214_Wenu_maxHTpTV2_CVe...  61345
# 6  43169658  mc23_13p6TeV.801166.Py8EG_A14NNPDF23LO_jj_JZ1....  61345
# 7  43169716  mc23_13p6TeV.601237.PhPy8EG_A14_ttbar_hdamp258...  61345
# 8  43169768  mc23_13p6TeV.701015.Sh_2214_llvvjj_ss.deriv.DA...  61345
# 9  43168790  mc20_13TeV.546041.MGPy8EG_A14N23LO_TT_tN1_1200...  61345
#
#                   SUBMIT_TIME                  START_TIME
# 0  2025-02-04 14:19:01.000000  2025-02-04 14:20:52.000000
# 1  2025-02-04 14:19:14.000000  2025-02-04 14:54:00.000000
# 2  2025-02-04 14:19:22.000000  2025-02-04 15:24:27.000000
# 3  2025-02-04 14:19:29.000000  2025-02-04 14:52:21.000000
# 4  2025-02-04 14:19:31.000000  2025-02-04 14:22:51.000000
# 5  2025-02-04 14:19:46.000000  2025-02-05 01:12:33.000000
# 6  2025-02-04 14:19:59.000000  2025-02-04 14:23:36.000000
# 7  2025-02-04 14:20:08.000000  2025-02-04 14:54:51.000000
# 8  2025-02-04 14:20:18.000000  2025-02-04 14:54:09.000000
# 9  2025-02-04 14:17:35.144607  2025-02-04 14:17:59.000000

# %%
prodsys_logs[prodsys_logs['dataset'] == 'mc16_13TeV:mc16_13TeV.364703.Pythia8EvtGen_A14NNPDF23LO_jetjet_JZ3WithSW.merge.EVNT.e7142_e5984_tid23096544_00']
# Out:
#                                        rule       resource  files  \
# 23     type=DATADISK&datapolicynucleus=True  IN2P3-CC_TAPE   1067
# 12743  type=DATADISK&datapolicynucleus=True  IN2P3-CC_TAPE   1067
#
#                   asctime                                            dataset  \
# 23    2021-12-10 13:26:12  mc16_13TeV:mc16_13TeV.364703.Pythia8EvtGen_A14...
# 12743 2022-03-31 18:38:56  mc16_13TeV:mc16_13TeV.364703.Pythia8EvtGen_A14...
#
#       dataset_origin year energy b_unit datasetid  \
# 23                mc   16     13    TeV    364703
# 12743             mc   16     13    TeV    364703
#
#                                    physics_process production_step  \
# 23     Pythia8EvtGen_A14NNPDF23LO_jetjet_JZ3WithSW           merge
# 12743  Pythia8EvtGen_A14NNPDF23LO_jetjet_JZ3WithSW           merge
#
#       data_format     ami_tags root_taskID
# 23           EVNT  e7142_e5984    23096544
# 12743        EVNT  e7142_e5984    23096544

# %%
prodsys_logs_2025 = prodsys_logs[prodsys_logs['asctime'] >= '2025-01-01']

# %%
# Step 1: Extract the dataset name from 'feb_24' by removing the part before ':'
prodsys_logs_2025['dataset_name'] = prodsys_logs_2025['dataset'].str.split(':').str[1]
# Out:
# /tmp/ipykernel_127889/2447210210.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prodsys_logs_2025['dataset_name'] = prodsys_logs_2025['dataset'].str.split(':').str[1]

# %%
prodsys_logs_2025.head()
# Out:
#                                                      rule       resource  \
# 115326  type=DATADISK&datapolicynucleus=True\(cloud=US...  IN2P3-CC_TAPE
# 115327  type=DATADISK&datapolicynucleus=True\(cloud=US...   INFN-T1_TAPE
# 115328  type=DATADISK&datapolicynucleus=True\(cloud=US...  IN2P3-CC_TAPE
# 115329  type=DATADISK&datapolicynucleus=True\(cloud=US...  IN2P3-CC_TAPE
# 115330  type=DATADISK&datapolicynucleus=True\(cloud=US...  IN2P3-CC_TAPE
#
#         files              asctime  \
# 115326  14971  2025-01-02 15:36:35
# 115327  14884  2025-01-02 15:44:19
# 115328      7  2025-01-06 19:37:54
# 115329      9  2025-01-06 19:37:54
# 115330      3  2025-01-06 19:37:55
#
#                                                   dataset dataset_origin  \
# 115326  mc16_13TeV:mc16_13TeV.426345.Pythia8EvtGen_A14...             mc
# 115327  mc16_13TeV:mc16_13TeV.426347.Pythia8EvtGen_A14...             mc
# 115328  mc20_13TeV:mc20_13TeV.545689.MGPy8EG_WpWmhjj_l...             mc
# 115329  mc20_13TeV:mc20_13TeV.545694.MGPy8EG_WpWphjj_l...             mc
# 115330  mc20_13TeV:mc20_13TeV.545708.MGPy8EG_WmWphjj_l...             mc
#
#         year  energy b_unit  datasetid  \
# 115326  16.0    13.0    TeV     426345
# 115327  16.0    13.0    TeV     426347
# 115328  20.0    13.0    TeV     545689
# 115329  20.0    13.0    TeV     545694
# 115330  20.0    13.0    TeV     545708
#
#                                     physics_process production_step  \
# 115326  Pythia8EvtGen_A14NNPDF23LO_Zprime_tt_flatpT           simul
# 115327   Pythia8EvtGen_A14NNPDF23LO_WprimeWZ_flatpT           simul
# 115328         MGPy8EG_WpWmhjj_lvqqbbjj_EW8_LO_klp1           merge
# 115329         MGPy8EG_WpWphjj_lvqqbbjj_EW8_LO_klp1           merge
# 115330         MGPy8EG_WmWphjj_lvqqbbjj_EW8_LO_klm5           merge
#
#        data_format                         ami_tags  root_taskID  \
# 115326        HITS                e6880_e5984_s3126   15249851.0
# 115327        HITS                e6880_e5984_s3126   15249855.0
# 115328         AOD  e8488_e8455_s3797_r13145_r13146   40372744.0
# 115329         AOD  e8488_e8455_s3797_r13145_r13146   40372752.0
# 115330         AOD   e8488_e8455_a907_r14861_r14919   40277352.0
#
#                                              dataset_name
# 115326  mc16_13TeV.426345.Pythia8EvtGen_A14NNPDF23LO_Z...
# 115327  mc16_13TeV.426347.Pythia8EvtGen_A14NNPDF23LO_W...
# 115328  mc20_13TeV.545689.MGPy8EG_WpWmhjj_lvqqbbjj_EW8...
# 115329  mc20_13TeV.545694.MGPy8EG_WpWphjj_lvqqbbjj_EW8...
# 115330  mc20_13TeV.545708.MGPy8EG_WmWphjj_lvqqbbjj_EW8...

# %%
# Merge DataFrames on dataset_name = inputdataset
merged_df = prodsys_logs_2025.merge(tasks_df, left_on="dataset_name", right_on="INPUTDATASET", how="inner")

# %%
matching_datasets = set(prodsys_logs_2025["dataset_name"]) & set(merged_df["INPUTDATASET"])
print(f"Matching dataset names: {matching_datasets}")
# Out:
# Matching dataset names: {'data24_13p6TeV.00483888.physics_ZeroBias.merge.AOD.f1510_m2248', 'data24_13p6TeV.00484653.physics_Main.daq.RAW', 'data24_13p6TeV.00476991.physics_ZeroBias.merge.AOD.f1472_m2248', 'data24_13p6TeV.00481166.physics_ZeroBias.merge.AOD.f1494_m2248', 'data24_13p6TeV.00486834.physics_Main.daq.RAW', 'data24_13p6TeV.00486273.physics_ZeroBias.merge.AOD.f1519_m2259', 'data24_13p6TeV.00476730.physics_ZeroBias.merge.AOD.f1470_m2248', 'data24_13p6TeV.00486211.physics_Main.daq.RAW', 'data24_13p6TeV.00476060.physics_ZeroBias.merge.AOD.f1468_m2248', 'data24_13p6TeV.00476033.physics_ZeroBias.merge.AOD.f1468_m2248', 'data24_13p6TeV.00480161.physics_ZeroBias.merge.AOD.f1492_m2248', 'data24_13p6TeV.00473317.physics_ZeroBias.merge.AOD.f1446_m2248', 'data24_13p6TeV.00475925.physics_ZeroBias.merge.AOD.f1468_m2248', 'data24_13p6TeV.00479239.physics_ZeroBias.merge.AOD.f1484_m2248', 'data24_13p6TeV.00481865.physics_ZeroBias.merge.AOD.f1498_m2248', 'data24_13p6TeV.00481013.physics_ZeroBias.merge.AOD.f1494_m2248', 'data24_13p6TeV.00480957.physics_ZeroBias.merge.AOD.f1494_m2248', 'data24_13p6TeV.00486179.physics_ZeroBias.merge.AOD.f1519_m2259', 'data24_13p6TeV.00486640.physics_Main.daq.RAW', 'data24_13p6TeV.00484016.physics_ZeroBias.merge.AOD.f1510_m2248', 'data24_13p6TeV.00476505.physics_ZeroBias.merge.AOD.f1470_m2248', 'data24_13p6TeV.00476760.physics_ZeroBias.merge.AOD.f1470_m2248', 'data24_13p6TeV.00474600.physics_ZeroBias.merge.AOD.f1462_m2248', 'data24_13p6TeV.00476265.physics_ZeroBias.merge.AOD.f1470_m2248', 'data24_13p6TeV.00486658.physics_Main.daq.RAW', 'data24_13p6TeV.00474254.physics_ZeroBias.merge.AOD.f1452_m2248', 'data24_13p6TeV.00483852.physics_Main.daq.RAW', 'data24_13p6TeV.00486262.physics_Main.daq.RAW', 'data24_13p6TeV.00482427.physics_ZeroBias.merge.AOD.f1500_m2248', 'data24_13p6TeV.00478662.physics_ZeroBias.merge.AOD.f1482_m2248', 'data24_13p6TeV.00485481.physics_ZeroBias.merge.AOD.f1518_m2248', 'data24_13p6TeV.00475884.physics_ZeroBias.merge.AOD.f1468_m2248', 'data24_13p6TeV.00486253.physics_ZeroBias.merge.AOD.f1519_m2259', 'data24_13p6TeV.00478663.physics_ZeroBias.merge.AOD.f1482_m2248', 'data24_13p6TeV.00479269.physics_ZeroBias.merge.AOD.f1484_m2248', 'data24_13p6TeV.00472943.physics_ZeroBias.merge.AOD.f1442_m2243', 'data24_13p6TeV.00481510.physics_ZeroBias.merge.AOD.f1496_m2248', 'data24_13p6TeV.00485649.physics_ZeroBias.merge.AOD.f1518_m2248', 'data24_13p6TeV.00479519.physics_ZeroBias.merge.AOD.f1486_m2248', 'data24_13p6TeV.00482374.physics_ZeroBias.merge.AOD.f1500_m2248', 'data24_13p6TeV.00483833.physics_ZeroBias.merge.AOD.f1510_m2248', 'data24_13p6TeV.00483532.physics_Main.daq.RAW', 'data24_13p6TeV.00473182.physics_ZeroBias.merge.AOD.f1444_m2248', 'data24_13p6TeV.00483684.physics_Main.daq.RAW', 'data24_13p6TeV.00484222.physics_Main.daq.RAW', 'data24_13p6TeV.00481277.physics_ZeroBias.merge.AOD.f1494_m2248', 'data24_13p6TeV.00482152.physics_ZeroBias.merge.AOD.f1498_m2248', 'data24_13p6TeV.00476396.physics_ZeroBias.merge.AOD.f1470_m2248', 'data24_13p6TeV.00485950.physics_Main.daq.RAW', 'data24_13p6TeV.00476007.physics_ZeroBias.merge.AOD.f1468_m2248', 'data24_13p6TeV.00480307.physics_ZeroBias.merge.AOD.f1492_m2248', 'data24_13p6TeV.00481591.physics_ZeroBias.merge.AOD.f1496_m2248', 'data24_13p6TeV.00485887.physics_ZeroBias.merge.AOD.f1519_m2259', 'data24_13p6TeV.00482485.physics_ZeroBias.merge.AOD.f1500_m2248', 'data24_13p6TeV.00483409.physics_ZeroBias.merge.AOD.f1506_m2248', 'data24_13p6TeV.00475944.physics_ZeroBias.merge.AOD.f1468_m2248', 'data24_13p6TeV.00482448.physics_ZeroBias.merge.AOD.f1500_m2248', 'data24_13p6TeV.00486131.physics_ZeroBias.merge.AOD.f1519_m2259', 'data24_13p6TeV.00476708.physics_ZeroBias.merge.AOD.f1470_m2248', 'data24_13p6TeV.00473095.physics_ZeroBias.merge.AOD.f1444_m2248', 'data24_13p6TeV.00484653.physics_ZeroBias.merge.AOD.f1514_m2248', 'data24_13p6TeV.00479449.physics_ZeroBias.merge.AOD.f1486_m2248', 'data24_13p6TeV.00483697.physics_ZeroBias.merge.AOD.f1510_m2248', 'data24_13p6TeV ...

# %%
merged_df.head()
# Out:
#                                                 rule           resource  \
# 0  type=DATADISK&datapolicynucleus=True\(cloud=US...  CERN-PROD_SPECIAL
# 1  type=DATADISK&datapolicynucleus=True\(cloud=US...  CERN-PROD_SPECIAL
# 2  type=DATADISK&datapolicynucleus=True\(cloud=US...  CERN-PROD_SPECIAL
# 3  type=DATADISK&datapolicynucleus=True\(cloud=US...  CERN-PROD_SPECIAL
# 4  type=DATADISK&datapolicynucleus=True\(cloud=US...  CERN-PROD_SPECIAL
#
#    files              asctime  \
# 0     18  2025-01-31 14:04:28
# 1   4901  2025-02-02 02:34:35
# 2     19  2025-02-02 13:34:48
# 3     18  2025-02-02 13:34:48
# 4     25  2025-02-02 13:34:49
#
#                                              dataset dataset_origin  year  \
# 0  data24_13p6TeV:data24_13p6TeV.00486894.physics...           data  24.0
# 1  data24_13p6TeV:data24_13p6TeV.00486706.physics...           data  24.0
# 2  data24_13p6TeV:data24_13p6TeV.00472553.physics...           data  24.0
# 3  data24_13p6TeV:data24_13p6TeV.00472578.physics...           data  24.0
# 4  data24_13p6TeV:data24_13p6TeV.00472604.physics...           data  24.0
#
#    energy b_unit  datasetid  ... production_step data_format     ami_tags  \
# 0    13.6    TeV     486894  ...           merge         AOD  f1524_m2259
# 1    13.6    TeV     486706  ...           merge         AOD  f1522_m2259
# 2    13.6    TeV     472553  ...           merge         AOD  f1437_m2243
# 3    13.6    TeV     472578  ...           merge         AOD  f1437_m2243
# 4    13.6    TeV     472604  ...           merge         AOD  f1437_m2243
#
#   root_taskID                                       dataset_name    TASKID  \
# 0         NaN  data24_13p6TeV.00486894.physics_ZeroBias.merge...  43131183
# 1         NaN  data24_13p6TeV.00486706.physics_Main.merge.AOD...  43296714
# 2         NaN  data24_13p6TeV.00472553.physics_ZeroBias.merge...  43140296
# 3         NaN  data24_13p6TeV.00472578.physics_ZeroBias.merge...  43140298
# 4         NaN  data24_13p6TeV.00472604.physics_ZeroBias.merge...  43140300
#
#                                         INPUTDATASET  PR_ID  \
# 0  data24_13p6TeV.00486894.physics_ZeroBias.merge...  61279
# 1  data24_13p6TeV.00486706.physics_Main.merge.AOD...  61579
# 2  data24_13p6TeV.00472553.physics_ZeroBias.merge...  61294
# 3  data24_13p6TeV.00472578.physics_ZeroBias.merge...  61294
# 4  data24_13p6TeV.00472604.physics_ZeroBias.merge...  61294
#
#                   SUBMIT_TIME                  START_TIME
# 0  2025-01-31 13:00:05.447953  2025-02-01 07:59:34.000000
# 1  2025-02-15 17:06:05.972072  2025-02-16 21:15:32.000000
# 2  2025-02-02 13:18:07.000000  2025-02-02 19:04:38.000000
# 3  2025-02-02 13:18:09.000000  2025-02-03 03:43:27.000000
# 4  2025-02-02 13:18:12.000000  2025-02-02 19:09:27.000000
#
# [5 rows x 21 columns]

# %%
merged_df.dtypes
# Out:
# rule                       object
# resource                   object
# files                       int64
# asctime            datetime64[ns]
# dataset                    object
# dataset_origin             object
# year                      float64
# energy                    float64
# b_unit                     object
# datasetid                   int64
# physics_process            object
# production_step            object
# data_format                object
# ami_tags                   object
# root_taskID               float64
# dataset_name               object
# TASKID                      int64
# INPUTDATASET               object
# PR_ID                       int64
# SUBMIT_TIME        datetime64[ns]
# START_TIME         datetime64[ns]
# dtype: object

# %%
merged_df['asctime'] = pd.to_datetime(merged_df['asctime'])
merged_df['SUBMIT_TIME'] = pd.to_datetime(merged_df['SUBMIT_TIME'])
merged_df['START_TIME'] = pd.to_datetime(merged_df['START_TIME'])

# %%
# Calculate time differences
merged_df["submit_to_asctime"] = (merged_df["asctime"] - merged_df["SUBMIT_TIME"]).dt.total_seconds() / 3600  # in hours
merged_df["asctime_to_start"] = (merged_df["START_TIME"] - merged_df["asctime"]).dt.total_seconds() / 3600  # in hours

# Drop redundant column (optional)
merged_df.drop(columns=["INPUTDATASET"], inplace=True)

# Display result
print(merged_df)
# Out:
#                                                   rule           resource  \
# 0    type=DATADISK&datapolicynucleus=True\(cloud=US...  CERN-PROD_SPECIAL
# 1    type=DATADISK&datapolicynucleus=True\(cloud=US...  CERN-PROD_SPECIAL
# 2    type=DATADISK&datapolicynucleus=True\(cloud=US...  CERN-PROD_SPECIAL
# 3    type=DATADISK&datapolicynucleus=True\(cloud=US...  CERN-PROD_SPECIAL
# 4    type=DATADISK&datapolicynucleus=True\(cloud=US...  CERN-PROD_SPECIAL
# ..                                                 ...                ...
# 341  type=DATADISK&datapolicynucleus=True\(cloud=US...      FZK-LCG2_TAPE
# 342  type=DATADISK&datapolicynucleus=True\(cloud=US...   SARA-MATRIX_TAPE
# 343  type=DATADISK&datapolicynucleus=True\(cloud=US...       INFN-T1_TAPE
# 344  type=DATADISK&datapolicynucleus=True\(cloud=US...       INFN-T1_TAPE
# 345  type=DATADISK&datapolicynucleus=True\(cloud=US...       INFN-T1_TAPE
#
#      files             asctime  \
# 0       18 2025-01-31 14:04:28
# 1     4901 2025-02-02 02:34:35
# 2       19 2025-02-02 13:34:48
# 3       18 2025-02-02 13:34:48
# 4       25 2025-02-02 13:34:49
# ..     ...                 ...
# 341    850 2025-02-16 04:09:00
# 342  11235 2025-02-16 11:09:15
# 343  35991 2025-02-16 12:39:12
# 344  11131 2025-02-16 12:39:15
# 345  44211 2025-02-16 12:39:18
#
#                                                dataset dataset_origin  year  \
# 0    data24_13p6TeV:data24_13p6TeV.00486894.physics...           data  24.0
# 1    data24_13p6TeV:data24_13p6TeV.00486706.physics...           data  24.0
# 2    data24_13p6TeV:data24_13p6TeV.00472553.physics...           data  24.0
# 3    data24_13p6TeV:data24_13p6TeV.00472578.physics...           data  24.0
# 4    data24_13p6TeV:data24_13p6TeV.00472604.physics...           data  24.0
# ..                                                 ...            ...   ...
# 341  data18_13TeV:data18_13TeV.00350682.physics_Mai...           data  18.0
# 342  data24_13p6TeV:data24_13p6TeV.00486689.physics...           data  24.0
# 343  data24_13p6TeV:data24_13p6TeV.00484146.physics...           data  24.0
# 344  data24_13p6TeV:data24_13p6TeV.00484222.physics...           data  24.0
# 345  data24_13p6TeV:data24_13p6TeV.00486179.physics...           data  24.0
#
#      energy b_unit  datasetid  ... data_format     ami_tags root_taskID  \
# 0      13.6    TeV     486894  ...         AOD  f1524_m2259         NaN
# 1      13.6    TeV     486706  ...         AOD  f1522_m2259         NaN
# 2      13.6    TeV     472553  ...         AOD  f1437_m2243         NaN
# 3      13.6    TeV     472578  ...         AOD  f1437_m2243         NaN
# 4      13.6    TeV     472604  ...         AOD  f1437_m2243         NaN
# ..      ...    ...        ...  ...         ...          ...         ...
# 341    13.0    TeV     350682  ...  DRAW_ZMUMU   f936_m1831         NaN
# 342    13.6    TeV     486689  ...         RAW          NaN         NaN
# 343    13.6    TeV     484146  ...         RAW          NaN         NaN
# 344    13.6    TeV     484222  ...         RAW          NaN         NaN
# 345    13.6    TeV     486179  ...         RAW          NaN         NaN
#
#                                           dataset_name    TASKID  PR_ID  \
# 0    data24_13p6TeV.00486894.physics_ZeroBias.merge...  43131183  61279
# 1    data24_13p6TeV.00486706.physics_Main.merge.AOD...  43296714  61579
# 2    data24_13p6TeV.00472553.physics_ZeroBias.merge...  43140296  61294
# 3    data24_13p6TeV.00472578.physics_ZeroBias.merge...  43140298  61294
# 4    data24_13p6TeV.00472604.physics_ZeroBias.merge...  43140300  61294
# ..                                                 ...       ...    ...
# 341  data18_13TeV.00350682.physics_Main.merge.DRAW_...  43243044  61467
# 342       data24_13p6TeV.00486689.physics_Main.daq.RAW  43166192  61333
# 343       data24_13p6TeV.00484146.physics_Main.daq.RAW  43165723  61333
# 344       data24_13p6TeV.00484222.physics_Main.daq.RAW  43165761  61333
# 345       data24_13p6TeV.00486179.physics_Main.daq.RAW  43166073  61333
#
#                    SUBMIT_TIME          START_TIME submit_to_asctime  \
# 0   2025-01-31 13:00:05.447953 2025-02-01 07:59:34          1.072931
# 1   2025-02-15 17:06:05.972072 2025-02-16 21:15:32       -326.525270
# 2   2025-02-02 13:18:07.000000 2025-02-02 19:04:38          0.278056
# 3   2025-02-02 13:18:09.000000 2025-02-03 03:43:27          0.277500
# 4   2025-02-02 13:18:12.000000 2025-02-02 19:09:27          0.276944
# ..                         ...                 ...               ...
# 341 2025-02-11 17:21:04.000000 2025-02-16 06:53:55        106.798889
# 342 2025-02-04 11:49:11.445467 2025-02-16 12:40:39        287.334321
# 343 2025-02-04 11:45:18.177717 2025-02-18 01:59:18        288.898284
# 344 2025-02-04 11:45:33.611798 2025-02-17 19:59:21        288.894830
# 345 2025-02-04 11:48:14.262832 2025-02-16 13:38:31        288.851038
#
#     asctime_to_start
# 0          17.918333
# 1         354.682500
# 2           5.497222
# 3          14.144167
# 4           5.577222
# ..               ...
# 341         2.748611
# 342         1.523333
# 343        37.335000
# 344        31.335000
# 345         0.986944
#
# [346 rows x 22 columns]

# %%
merged_df[['dataset_name', 'asctime', 'SUBMIT_TIME', 'START_TIME', 'submit_to_asctime', 'asctime_to_start']].head(10)
# Out:
#                                          dataset_name             asctime  \
# 0   data24_13p6TeV.00486894.physics_ZeroBias.merge... 2025-01-31 14:04:28
# 2   data24_13p6TeV.00472553.physics_ZeroBias.merge... 2025-02-02 13:34:48
# 3   data24_13p6TeV.00472578.physics_ZeroBias.merge... 2025-02-02 13:34:48
# 4   data24_13p6TeV.00472604.physics_ZeroBias.merge... 2025-02-02 13:34:49
# 5   data24_13p6TeV.00472632.physics_ZeroBias.merge... 2025-02-02 13:34:50
# 6   data24_13p6TeV.00472633.physics_ZeroBias.merge... 2025-02-02 13:34:50
# 7   data24_13p6TeV.00472634.physics_ZeroBias.merge... 2025-02-02 13:34:50
# 8   data24_13p6TeV.00472662.physics_ZeroBias.merge... 2025-02-02 13:34:51
# 9   data24_13p6TeV.00472677.physics_ZeroBias.merge... 2025-02-02 13:34:51
# 10  data24_13p6TeV.00472807.physics_ZeroBias.merge... 2025-02-02 13:34:51
#
#                   SUBMIT_TIME          START_TIME  submit_to_asctime  \
# 0  2025-01-31 13:00:05.447953 2025-02-01 07:59:34           1.072931
# 2  2025-02-02 13:18:07.000000 2025-02-02 19:04:38           0.278056
# 3  2025-02-02 13:18:09.000000 2025-02-03 03:43:27           0.277500
# 4  2025-02-02 13:18:12.000000 2025-02-02 19:09:27           0.276944
# 5  2025-02-02 13:18:14.000000 2025-02-02 19:04:39           0.276667
# 6  2025-02-02 13:18:15.686416 2025-02-02 19:09:24           0.276198
# 7  2025-02-02 13:18:17.718663 2025-02-02 19:09:29           0.275634
# 8  2025-02-02 13:18:19.937370 2025-02-15 08:43:41           0.275295
# 9  2025-02-02 13:18:21.957316 2025-02-02 19:09:26           0.274734
# 10 2025-02-02 13:18:24.095901 2025-02-02 19:09:23           0.274140
#
#     asctime_to_start
# 0          17.918333
# 2           5.497222
# 3          14.144167
# 4           5.577222
# 5           5.496944
# 6           5.576111
# 7           5.577500
# 8         307.147222
# 9           5.576389
# 10          5.575556

# %%
merged_df = merged_df[(merged_df['submit_to_asctime'] >= 0) & (merged_df['asctime_to_start'] >= 0)]

# %%
merged_df[merged_df['submit_to_asctime'] > 288]
# Out:
#                                                   rule      resource  files  \
# 343  type=DATADISK&datapolicynucleus=True\(cloud=US...  INFN-T1_TAPE  35991
# 344  type=DATADISK&datapolicynucleus=True\(cloud=US...  INFN-T1_TAPE  11131
# 345  type=DATADISK&datapolicynucleus=True\(cloud=US...  INFN-T1_TAPE  44211
#
#                 asctime                                            dataset  \
# 343 2025-02-16 12:39:12  data24_13p6TeV:data24_13p6TeV.00484146.physics...
# 344 2025-02-16 12:39:15  data24_13p6TeV:data24_13p6TeV.00484222.physics...
# 345 2025-02-16 12:39:18  data24_13p6TeV:data24_13p6TeV.00486179.physics...
#
#     dataset_origin  year  energy b_unit  datasetid  ... data_format ami_tags  \
# 343           data  24.0    13.6    TeV     484146  ...         RAW      NaN
# 344           data  24.0    13.6    TeV     484222  ...         RAW      NaN
# 345           data  24.0    13.6    TeV     486179  ...         RAW      NaN
#
#     root_taskID                                  dataset_name    TASKID  \
# 343         NaN  data24_13p6TeV.00484146.physics_Main.daq.RAW  43165723
# 344         NaN  data24_13p6TeV.00484222.physics_Main.daq.RAW  43165761
# 345         NaN  data24_13p6TeV.00486179.physics_Main.daq.RAW  43166073
#
#      PR_ID                SUBMIT_TIME          START_TIME submit_to_asctime  \
# 343  61333 2025-02-04 11:45:18.177717 2025-02-18 01:59:18        288.898284
# 344  61333 2025-02-04 11:45:33.611798 2025-02-17 19:59:21        288.894830
# 345  61333 2025-02-04 11:48:14.262832 2025-02-16 13:38:31        288.851038
#
#     asctime_to_start
# 343        37.335000
# 344        31.335000
# 345         0.986944
#
# [3 rows x 22 columns]

# %%
merged_df[['dataset_name', 'asctime', 'SUBMIT_TIME', 'START_TIME', 'submit_to_asctime', 'asctime_to_start']].describe()
# Out:
#                              asctime                    SUBMIT_TIME  \
# count                            345                            345
# mean   2025-02-03 13:06:52.142029056  2025-02-02 22:08:46.759607808
# min              2025-01-31 14:04:28     2025-01-31 13:00:05.447953
# 25%              2025-02-02 13:34:59            2025-02-02 13:21:07
# 50%              2025-02-02 13:35:07            2025-02-02 13:24:10
# 75%              2025-02-02 14:04:52  2025-02-02 13:27:16.172655104
# max              2025-02-16 12:39:18            2025-02-11 17:21:17
# std                              NaN                            NaN
#
#                           START_TIME  submit_to_asctime  asctime_to_start
# count                            345         345.000000        345.000000
# mean   2025-02-04 21:56:02.718840832          14.968162         32.819605
# min              2025-02-01 07:59:34           0.157862          0.986944
# 25%              2025-02-02 19:14:35           0.206807          5.500000
# 50%              2025-02-02 21:13:41           0.255377          5.779444
# 75%              2025-02-04 20:28:29           0.633611         12.350278
# max              2025-02-25 10:32:15         288.898284        478.941667
# std                              NaN          46.958671         79.738830

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select the relevant columns
df_plot = merged_df[['submit_to_asctime', 'asctime_to_start']]

# Function to remove outliers using IQR
def remove_outliers(df, columns):
    filtered_df = df.copy()
    for col in columns:
        Q1 = filtered_df[col].quantile(0.25)
        Q3 = filtered_df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        filtered_df = filtered_df[(filtered_df[col] >= lower_bound) & (filtered_df[col] <= upper_bound)]
    return filtered_df

# Remove outliers
df_clean = remove_outliers(df_plot, ['submit_to_asctime', 'asctime_to_start'])

# Transform data for boxplot (convert from wide to long format)
df_melted = df_clean.melt(var_name="Time Interval", value_name="Hours")

# Create the boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(x="Time Interval", y="Hours", data=df_melted)

# Add title and labels
plt.title("Distribution of Time Intervals (Outliers Removed)")
plt.xlabel("Time Interval")
plt.ylabel("Hours")

# Show the plot
plt.show()

# %%
rules = pd.read_csv('rucio_rules_feb_2024.csv')
# Out:
# /tmp/ipykernel_120260/3105205117.py:1: DtypeWarning: Columns (11,14,23,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   rules = pd.read_csv('rucio_rules_feb_2024.csv')

# %%
rules.head(1000)
# Out:
#      Unnamed: 0                                                 ID  \
# 0             0  bytearray(b'D\xe3\xbe\xc5\xf1\xfdNQ\x9f;\xa3/\...
# 1             1  bytearray(b'U\x84\xb8\xc5=bH\x98\xb8\xa7hz\xd0...
# 2             2  bytearray(b'\xbf\xdd\xb8jep@;\xb2\xff[\xaf\xc7...
# 3             3  bytearray(b'\xca\xd8\xb4\\\x93SC\xf9\x85{\xf8\...
# 4             4  bytearray(b'"vW_\x07\xf6DE\x99\xee\xa8\xb7\xc8...
# ..          ...                                                ...
# 995         995  bytearray(b'7\xcb\x18l\xe4\r@\xf1\xa7\x93\x01\...
# 996         996  bytearray(b'\x9a\x7fm\xda\xe6\xf5O\x85\x95f\x8...
# 997         997  bytearray(b"\'\x89\xcc\xaa\xd4\xd0D[\xb6\xf6\x...
# 998         998  bytearray(b'\xba\x00\xfc\x99I\x03LW\xa3q\x07\x...
# 999         999  bytearray(b"\xba\x1d\x00/c\xa7DS\xa2\xdd\xca\x...
#
#                                        SUBSCRIPTION_ID   ACCOUNT  \
# 0                                                  NaN     pilot
# 1                                                  NaN     pilot
# 2                                                  NaN     pilot
# 3                                                  NaN     pilot
# 4                                                  NaN     pilot
# ..                                                 ...       ...
# 995  bytearray(b'\x90?\xf2\xb2\xb8\x85KX\x95\x86\x8...  ddmadmin
# 996                                                NaN     tzero
# 997  bytearray(b'\x90?\xf2\xb2\xb8\x85KX\x95\x86\x8...  ddmadmin
# 998                                                NaN     tzero
# 999  bytearray(b'\x90?\xf2\xb2\xb8\x85KX\x95\x86\x8...  ddmadmin
#
#             SCOPE                                               NAME DID_TYPE  \
# 0     cond09_test                        cond09_test.000048.gen.COND        D
# 1     cond09_test                        cond09_test.000048.gen.COND        D
# 2     cond09_test                        cond09_test.000048.gen.COND        D
# 3     cond09_test                        cond09_test.000049.gen.COND        D
# 4     cond09_test                        cond09_test.000049.gen.COND        D
# ..            ...                                                ...      ...
# 995  data24_calib  data24_calib.00468290.calibration_LArElec-Ramp...        D
# 996  data24_calib  data24_calib.00468290.calibration_LArElec-Ramp...        D
# 997  data24_calib  data24_calib.00468291.calibration_LArElec-Ramp...        D
# 998  data24_calib  data24_calib.00468291.calibration_LArElec-Ramp...        D
# 999  data24_calib  data24_calib.00468292.calibration_LArElec-Ramp...        D
#
#     STATE      RSE_EXPRESSION  COPIES  ... STUCK_AT PURGE_REPLICAS  \
# 0       O   BNL-OSG2_DATADISK     1.0  ...      NaN            0.0
# 1       O   CERN-PROD_HOTDISK     1.0  ...      NaN            0.0
# 2       O  CERN-PROD_DATATAPE     1.0  ...      NaN            0.0
# 3       O  CERN-PROD_DATATAPE     1.0  ...      NaN            0.0
# 4       O   BNL-OSG2_DATADISK     1.0  ...      NaN            0.0
# ..    ...                 ...     ...  ...      ...            ...
# 995     O   RAL-LCG2_DATATAPE     1.0  ...      NaN            0.0
# 996     O       CERN-PROD_RAW     1.0  ...      NaN            0.0
# 997     O   BNL-OSG2_DATATAPE     1.0  ...      NaN            0.0
# 998     O       CERN-PROD_RAW     1.0  ...      NaN            0.0
# 999     O    INFN-T1_DATATAPE     1.0  ...      NaN            0.0
#
#      IGNORE_AVAILABILITY           COMMENTS IGNORE_ACCOUNT_LIMIT  \
# 0                    0.0                NaN                  0.0
# 1                    0.0                NaN                  0.0
# 2                    0.0                NaN                  0.0
# 3                    0.0                NaN                  0.0
# 4                    0.0                NaN                  0.0
# ..                   ...                ...                  ...
# 995                  0.0  T0 RAW to T1 tape                  0.0
# 996                  1.0                NaN                  0.0
# 997                  0.0  T0 RAW to T1 tape                  0.0
# 998                  1.0                NaN                  0.0
# 999                  0.0  T0 RAW to T1 tape                  0.0
#
#     CHILD_RULE_ID PRIORITY               EOL_AT  SPLIT_CONTAINER  META
# 0             NaN      3.0                  NaN              0.0   NaN
# 1             NaN      3.0                  NaN              0.0   NaN
# 2             NaN      3.0                  NaN              0.0   NaN
# 3             NaN      3.0                  NaN              0.0   NaN
# 4             NaN      3.0                  NaN              0.0   NaN
# ..            ...      ...                  ...              ...   ...
# 995           NaN      3.0  2124-02-01 11:31:09              0.0   NaN
# 996           NaN      3.0  2124-02-01 11:31:09              0.0   NaN
# 997           NaN      3.0  2124-02-01 11:31:09              0.0   NaN
# 998           NaN      3.0  2124-02-01 11:31:09              0.0   NaN
# 999           NaN      3.0  2124-02-01 11:36:19              0.0   NaN
#
# [1000 rows x 33 columns]

# %%
rules.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'SUBSCRIPTION_ID', 'ACCOUNT', 'SCOPE', 'NAME',
#        'DID_TYPE', 'STATE', 'RSE_EXPRESSION', 'COPIES', 'EXPIRES_AT', 'WEIGHT',
#        'LOCKED', 'GROUPING', 'ERROR', 'UPDATED_AT', 'CREATED_AT',
#        'LOCKS_OK_CNT', 'LOCKS_REPLICATING_CNT', 'LOCKS_STUCK_CNT',
#        'SOURCE_REPLICA_EXPRESSION', 'ACTIVITY', 'NOTIFICATION', 'STUCK_AT',
#        'PURGE_REPLICAS', 'IGNORE_AVAILABILITY', 'COMMENTS',
#        'IGNORE_ACCOUNT_LIMIT', 'CHILD_RULE_ID', 'PRIORITY', 'EOL_AT',
#        'SPLIT_CONTAINER', 'META'],
#       dtype='object')

# %%
# Step 2: Merge the DataFrames on the dataset name
merged_df = feb_2024.merge(
    rules[['NAME', 'CREATED_AT', 'UPDATED_AT', 'EXPIRES_AT']], 
    left_on='dataset_name', 
    right_on='NAME', 
    how='left'
)

# Step 3: Rename the columns and add them to feb_24
merged_df['rucio_created_at'] = merged_df['CREATED_AT']
merged_df['rucio_updated_at'] = merged_df['UPDATED_AT']
merged_df['rucio_expires_at'] = merged_df['EXPIRES_AT']

# %%
merged_df = merged_df.drop(columns=['dataset_name', 'NAME', 'CREATED_AT', 'UPDATED_AT', 'EXPIRES_AT'])

# %%
print(merged_df[['dataset', 'rucio_created_at', 'rucio_updated_at', 'rucio_expires_at']])
# Out:
#                                                 dataset rucio_created_at  \
# 0     mc16_13TeV:mc16_13TeV.700324.Sh_2211_Zmumu_max...              NaN
# 1     mc16_13TeV:mc16_13TeV.700324.Sh_2211_Zmumu_max...              NaN
# 2     mc16_13TeV:mc16_13TeV.700335.Sh_2211_Znunu_pTV...              NaN
# 3     mc16_13TeV:mc16_13TeV.700335.Sh_2211_Znunu_pTV...              NaN
# 4     mc16_13TeV:mc16_13TeV.364200.Sherpa_221_NN30NN...              NaN
# ...                                                 ...              ...
# 2564  data17_13TeV:data17_13TeV.00333487.physics_Mai...              NaN
# 2565  data16_13TeV:data16_13TeV.00308047.physics_Mai...              NaN
# 2566  data17_13TeV:data17_13TeV.00333469.physics_Mai...              NaN
# 2567  data16_13TeV:data16_13TeV.00309375.physics_Mai...              NaN
# 2568  data16_13TeV:data16_13TeV.00309640.physics_Mai...              NaN
#
#      rucio_updated_at rucio_expires_at
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN
# ...               ...              ...
# 2564              NaN              NaN
# 2565              NaN              NaN
# 2566              NaN              NaN
# 2567              NaN              NaN
# 2568              NaN              NaN
#
# [2569 rows x 4 columns]

# %%
merged_df[merged_df['rucio_created_at'] != None]
# Out:
#                                                    rule          resource  \
# 0     type=DATADISK&datapolicynucleus=True&(cloud=US...    BNL-ATLAS_TAPE
# 1     type=DATADISK&datapolicynucleus=True&(cloud=US...    BNL-ATLAS_TAPE
# 2     type=DATADISK&datapolicynucleus=True&(cloud=US...    BNL-ATLAS_TAPE
# 3     type=DATADISK&datapolicynucleus=True&(cloud=US...    BNL-ATLAS_TAPE
# 4     type=DATADISK&datapolicynucleus=True\(cloud=US...     FZK-LCG2_TAPE
# ...                                                 ...               ...
# 2564  type=DATADISK&datapolicynucleus=True\(cloud=US...     RAL-LCG2_TAPE
# 2565  type=DATADISK&datapolicynucleus=True\(cloud=US...     RAL-LCG2_TAPE
# 2566  type=DATADISK&datapolicynucleus=True&(cloud=US...  TRIUMF-LCG2_TAPE
# 2567  type=DATADISK&datapolicynucleus=True&(cloud=US...  TRIUMF-LCG2_TAPE
# 2568  type=DATADISK&datapolicynucleus=True&(cloud=US...  TRIUMF-LCG2_TAPE
#
#       files             asctime  \
# 0      9978 2024-02-01 06:39:04
# 1     49909 2024-02-01 06:39:04
# 2      9997 2024-02-01 06:39:04
# 3     45930 2024-02-01 06:39:04
# 4       240 2024-02-01 07:39:05
# ...     ...                 ...
# 2564   6454 2024-02-29 06:18:36
# 2565  11653 2024-02-29 06:18:38
# 2566   2329 2024-02-29 06:18:42
# 2567   3091 2024-02-29 06:18:42
# 2568   9506 2024-02-29 06:18:44
#
#                                                 dataset dataset_origin year  \
# 0     mc16_13TeV:mc16_13TeV.700324.Sh_2211_Zmumu_max...             mc   16
# 1     mc16_13TeV:mc16_13TeV.700324.Sh_2211_Zmumu_max...             mc   16
# 2     mc16_13TeV:mc16_13TeV.700335.Sh_2211_Znunu_pTV...             mc   16
# 3     mc16_13TeV:mc16_13TeV.700335.Sh_2211_Znunu_pTV...             mc   16
# 4     mc16_13TeV:mc16_13TeV.364200.Sherpa_221_NN30NN...             mc   16
# ...                                                 ...            ...  ...
# 2564  data17_13TeV:data17_13TeV.00333487.physics_Mai...           data   17
# 2565  data16_13TeV:data16_13TeV.00308047.physics_Mai...           data   16
# 2566  data17_13TeV:data17_13TeV.00333469.physics_Mai...           data   17
# 2567  data16_13TeV:data16_13TeV.00309375.physics_Mai...           data   16
# 2568  data16_13TeV:data16_13TeV.00309640.physics_Mai...           data   16
#
#      energy b_unit datasetid  \
# 0        13    TeV    700324
# 1        13    TeV    700324
# 2        13    TeV    700335
# 3        13    TeV    700335
# 4        13    TeV    364200
# ...     ...    ...       ...
# 2564     13    TeV  00333487
# 2565     13    TeV  00308047
# 2566     13    TeV  00333469
# 2567     13    TeV  00309375
# 2568     13    TeV  00309640
#
#                                         physics_process production_step  \
# 0                  Sh_2211_Zmumu_maxHTpTV2_CFilterBVeto           simul
# 1                  Sh_2211_Zmumu_maxHTpTV2_CFilterBVeto           simul
# 2                            Sh_2211_Znunu_pTV2_BFilter           merge
# 3                            Sh_2211_Znunu_pTV2_BFilter           simul
# 4     Sherpa_221_NN30NNLO_Zmm_Mll10_40_MAXHTPTV70_28...           merge
# ...                                                 ...             ...
# 2564                                       physics_Main           recon
# 2565                                       physics_Main           recon
# 2566                                       physics_Main           recon
# 2567                                       physics_Main           recon
# 2568                                       physics_Main           recon
#
#      data_format                         ami_tags root_taskID  \
# 0           HITS                e8351_e7400_s3126    29973945
# 1           HITS                e8351_e7400_s3126    29878398
# 2           HITS          e8351_e7400_s3126_s3136    30877630
# 3           HITS                e8351_e7400_s3126    30523833
# 4            AOD  e5421_e5984_s3126_r10724_r10726    14874395
# ...          ...                              ...         ...
# 2564  DRAW_RPVLL                           r11782    20624343
# 2565  DRAW_RPVLL                           r11782    20777294
# 2566  DRAW_RPVLL                           r11782    20624339
# 2567  DRAW_RPVLL                           r11782    20777303
# 2568  DRAW_RPVLL                           r11782    20777320
#
#      rucio_created_at rucio_updated_at rucio_expires_at
# 0                 NaN              NaN              NaN
# 1                 NaN              NaN              NaN
# 2                 NaN              NaN              NaN
# 3                 NaN              NaN              NaN
# 4                 NaN              NaN              NaN
# ...               ...              ...              ...
# 2564              NaN              NaN              NaN
# 2565              NaN              NaN              NaN
# 2566              NaN              NaN              NaN
# 2567              NaN              NaN              NaN
# 2568              NaN              NaN              NaN
#
# [2569 rows x 18 columns]

# %%
# Step 1: Ensure 'created_at' and 'rucio_created_at' are in datetime format
merged_df['asctime'] = pd.to_datetime(merged_df['asctime'])
merged_df['rucio_created_at'] = pd.to_datetime(merged_df['rucio_created_at'])

# Step 2: Calculate the time difference and convert to milliseconds
merged_df['time_diff_ms'] = (merged_df['rucio_created_at'] - merged_df['asctime']).dt.total_seconds() * 1000

# Step 3: Check the resulting DataFrame
print(merged_df[['dataset', 'rucio_created_at', 'asctime', 'time_diff_ms']])
# Out:
#                                                 dataset rucio_created_at  \
# 0     mc16_13TeV:mc16_13TeV.700324.Sh_2211_Zmumu_max...              NaT
# 1     mc16_13TeV:mc16_13TeV.700324.Sh_2211_Zmumu_max...              NaT
# 2     mc16_13TeV:mc16_13TeV.700335.Sh_2211_Znunu_pTV...              NaT
# 3     mc16_13TeV:mc16_13TeV.700335.Sh_2211_Znunu_pTV...              NaT
# 4     mc16_13TeV:mc16_13TeV.364200.Sherpa_221_NN30NN...              NaT
# ...                                                 ...              ...
# 2564  data17_13TeV:data17_13TeV.00333487.physics_Mai...              NaT
# 2565  data16_13TeV:data16_13TeV.00308047.physics_Mai...              NaT
# 2566  data17_13TeV:data17_13TeV.00333469.physics_Mai...              NaT
# 2567  data16_13TeV:data16_13TeV.00309375.physics_Mai...              NaT
# 2568  data16_13TeV:data16_13TeV.00309640.physics_Mai...              NaT
#
#                  asctime  time_diff_ms
# 0    2024-02-01 06:39:04           NaN
# 1    2024-02-01 06:39:04           NaN
# 2    2024-02-01 06:39:04           NaN
# 3    2024-02-01 06:39:04           NaN
# 4    2024-02-01 07:39:05           NaN
# ...                  ...           ...
# 2564 2024-02-29 06:18:36           NaN
# 2565 2024-02-29 06:18:38           NaN
# 2566 2024-02-29 06:18:42           NaN
# 2567 2024-02-29 06:18:42           NaN
# 2568 2024-02-29 06:18:44           NaN
#
# [2569 rows x 4 columns]

# %%
merged_df[merged_df['time_diff_ms'] != None]
# Out:
#                                                    rule          resource  \
# 0     type=DATADISK&datapolicynucleus=True&(cloud=US...    BNL-ATLAS_TAPE
# 1     type=DATADISK&datapolicynucleus=True&(cloud=US...    BNL-ATLAS_TAPE
# 2     type=DATADISK&datapolicynucleus=True&(cloud=US...    BNL-ATLAS_TAPE
# 3     type=DATADISK&datapolicynucleus=True&(cloud=US...    BNL-ATLAS_TAPE
# 4     type=DATADISK&datapolicynucleus=True\(cloud=US...     FZK-LCG2_TAPE
# ...                                                 ...               ...
# 2564  type=DATADISK&datapolicynucleus=True\(cloud=US...     RAL-LCG2_TAPE
# 2565  type=DATADISK&datapolicynucleus=True\(cloud=US...     RAL-LCG2_TAPE
# 2566  type=DATADISK&datapolicynucleus=True&(cloud=US...  TRIUMF-LCG2_TAPE
# 2567  type=DATADISK&datapolicynucleus=True&(cloud=US...  TRIUMF-LCG2_TAPE
# 2568  type=DATADISK&datapolicynucleus=True&(cloud=US...  TRIUMF-LCG2_TAPE
#
#       files             asctime  \
# 0      9978 2024-02-01 06:39:04
# 1     49909 2024-02-01 06:39:04
# 2      9997 2024-02-01 06:39:04
# 3     45930 2024-02-01 06:39:04
# 4       240 2024-02-01 07:39:05
# ...     ...                 ...
# 2564   6454 2024-02-29 06:18:36
# 2565  11653 2024-02-29 06:18:38
# 2566   2329 2024-02-29 06:18:42
# 2567   3091 2024-02-29 06:18:42
# 2568   9506 2024-02-29 06:18:44
#
#                                                 dataset dataset_origin year  \
# 0     mc16_13TeV:mc16_13TeV.700324.Sh_2211_Zmumu_max...             mc   16
# 1     mc16_13TeV:mc16_13TeV.700324.Sh_2211_Zmumu_max...             mc   16
# 2     mc16_13TeV:mc16_13TeV.700335.Sh_2211_Znunu_pTV...             mc   16
# 3     mc16_13TeV:mc16_13TeV.700335.Sh_2211_Znunu_pTV...             mc   16
# 4     mc16_13TeV:mc16_13TeV.364200.Sherpa_221_NN30NN...             mc   16
# ...                                                 ...            ...  ...
# 2564  data17_13TeV:data17_13TeV.00333487.physics_Mai...           data   17
# 2565  data16_13TeV:data16_13TeV.00308047.physics_Mai...           data   16
# 2566  data17_13TeV:data17_13TeV.00333469.physics_Mai...           data   17
# 2567  data16_13TeV:data16_13TeV.00309375.physics_Mai...           data   16
# 2568  data16_13TeV:data16_13TeV.00309640.physics_Mai...           data   16
#
#      energy b_unit datasetid  \
# 0        13    TeV    700324
# 1        13    TeV    700324
# 2        13    TeV    700335
# 3        13    TeV    700335
# 4        13    TeV    364200
# ...     ...    ...       ...
# 2564     13    TeV  00333487
# 2565     13    TeV  00308047
# 2566     13    TeV  00333469
# 2567     13    TeV  00309375
# 2568     13    TeV  00309640
#
#                                         physics_process production_step  \
# 0                  Sh_2211_Zmumu_maxHTpTV2_CFilterBVeto           simul
# 1                  Sh_2211_Zmumu_maxHTpTV2_CFilterBVeto           simul
# 2                            Sh_2211_Znunu_pTV2_BFilter           merge
# 3                            Sh_2211_Znunu_pTV2_BFilter           simul
# 4     Sherpa_221_NN30NNLO_Zmm_Mll10_40_MAXHTPTV70_28...           merge
# ...                                                 ...             ...
# 2564                                       physics_Main           recon
# 2565                                       physics_Main           recon
# 2566                                       physics_Main           recon
# 2567                                       physics_Main           recon
# 2568                                       physics_Main           recon
#
#      data_format                         ami_tags root_taskID  \
# 0           HITS                e8351_e7400_s3126    29973945
# 1           HITS                e8351_e7400_s3126    29878398
# 2           HITS          e8351_e7400_s3126_s3136    30877630
# 3           HITS                e8351_e7400_s3126    30523833
# 4            AOD  e5421_e5984_s3126_r10724_r10726    14874395
# ...          ...                              ...         ...
# 2564  DRAW_RPVLL                           r11782    20624343
# 2565  DRAW_RPVLL                           r11782    20777294
# 2566  DRAW_RPVLL                           r11782    20624339
# 2567  DRAW_RPVLL                           r11782    20777303
# 2568  DRAW_RPVLL                           r11782    20777320
#
#      rucio_created_at rucio_updated_at rucio_expires_at  time_diff_ms
# 0                 NaT              NaN              NaN           NaN
# 1                 NaT              NaN              NaN           NaN
# 2                 NaT              NaN              NaN           NaN
# 3                 NaT              NaN              NaN           NaN
# 4                 NaT              NaN              NaN           NaN
# ...               ...              ...              ...           ...
# 2564              NaT              NaN              NaN           NaN
# 2565              NaT              NaN              NaN           NaN
# 2566              NaT              NaN              NaN           NaN
# 2567              NaT              NaN              NaN           NaN
# 2568              NaT              NaN              NaN           NaN
#
# [2569 rows x 19 columns]

# %%
import matplotlib.pyplot as plt

# Plot daily record counts
plt.figure(figsize=(12, 6))
plt.plot(daily_counts_pd['day'], daily_counts_pd['record_count'], marker='o', linestyle='-')
plt.title('Number of Records per Day [2025/02/13]')
plt.xlabel('Date')
plt.ylabel('Number of Records')
plt.grid(True)
plt.tight_layout()
plt.show()
